# %%
import numpy as np
import pandas as pd

# Display the dataframe
pd.set_option('display.max_columns', 100)  # or 1000
pd.set_option('display.max_rows', 100)  # or 1000
pd.set_option('display.max_colwidth', 100)  # or 199

# %% [markdown]
# ## GVB

# %%
gvb_checkin_hourly = pd.read_csv("../data/gvb/check_ins_hourly.csv", sep=';')

# %%
gvb_checkout_hourly = pd.read_csv("../data/gvb/check_outs_hourly.csv", sep=';')

# %%
gvb_checkin_hourly.HalteNaam.unique()
# Out:
# array(['Nieuwmarkt', 'Laan v.Vlaanderen', 'Lambertus Zijlplein',
#        'Leidseplein', 'Linnaeusstraat', 'Louis Davidsstraat', 'Louwesweg',
#        'Lumi?restraat', 'Lutmastraat', 'Maasstraat', 'La Guardiaweg',
#        'Marco Polostraat', 'Marnixplein', 'Marnixstraat', 'Matterhorn',
#        'Meer en Vaart', 'Mercatorplein', 'Meteorenweg',
#        'Michel de Klerkhof', 'Molenwerf', 'Molenwijk',
#        'Marie Heinekenplein', 'Molukkenstraat', 'Kruislaan',
#        'Kraaienneststation', 'Inaristraat', 'Insulindeweg', 'Isolatorweg',
#        'J.P. Heijestraat', 'Jan Tooropstraat', 'Jan Voermanstraat',
#        'Jan Zwanenburghof', 'Jan v.Galenstraat', 'Javaplein',
#        'Kronenburg', 'Johan Huizingalaan', 'Kabelweg', 'Kadijksplein',
#        'Kasterleepark', 'Kattenburgerstraat', 'Keizersgracht',
#        'Kinkerstraat', 'Koivistokade', 'Koningsplein',
#        'Kostverlorenstraat', "K. 's-Gravesandestr.", 'IJburg',
#        'Mr. Visserplein', 'Muntplein', 'Poortwachter', 'Postjesweg',
#        'Prins Hendrikkade', 'Prinsengracht', 'Reigersbos',
#        'Rembrandtplein', 'Rhijnvis Feithstraat', 'Rietlandpark',
#        'Rijksmuseum', 'Pontanusstraat', 'Roelof Hartplein', 'Rozengracht',
#        'Sacharovlaan', 'Sam van Houtenstraat', 'Scheldestraat',
#        'Schiphol Airport/Plaza', 'Schoolstraat', 'Science Park Terra',
#        'Slotermeerlaan', 'Sneeuwbalstraat', 'Rokin', 'Muiderpoortstation',
#        "Plein '40 - '45", 'Pilatus', 'Museumplein', 'Muziekgeb. Bimhuis',
#        'Nassaukade', 'Nic. Lublinkstraat', 'Nieuwezijds Kolk', 'Noord',
#        'Noorderpark', 'Oeverpad', 'Plantage Lepellaan', 'Olof Palmeplein',
#        'Olympiaweg', 'Olympisch stadion', 'Oostpoort', 'Oranjebaan',
#        'Osdorpplein', 'Oudenaardeplantsoen', 'Ouderkerkerlaan',
#        'Overamstel', 'Overtoom', 'Olympiaplein', 'Hugo de Vrieslaan',
#        'Hugo de Grootplein', 'Hoogte Kadijk', '2e v.d.Helststraat',
#        'A.J. Ernststraat', 'Aalbersestraat', 'Adm. Helfrichstraat',
#        'Adm. de Ruijterweg', 'Alexanderplein', 'Amsteldijk', 'Amstelkade',
#        'Amstelstation', '1e v.Swindenstraat', 'Amstelveenseweg',
#        'Arent Krijtsstraat', 'Artis', 'Assendelftstraat',
#        'Baden Powellweg', 'Barentszplein', 'Beemsterstraat', 'Beukenweg',
#        'Bilderdijkstraat', 'Binnenhof', 'Anton de Komplein',
#        'Bos en Lommerplein', '1e Leeghwaterstraat', '1e Coehoornstraat',
#        'Volendammerweg', 'Voordek', 'W. Schoutenstraat', 'Waalstraat',
#        'Waterlandplein', 'Waterlooplein', 'Weesperplein', 'Westermarkt',
#        'Westlandgracht', '1e Con. Huygensstraat', 'Westwijk',
#        'Wijttenbachstraat', 'Willem de Zwijgerlaan', 'Wiltzanghlaan',
#        'Witte de Withstraat', 'Zaanstraat', 'Zeeburgerdijk', 'Zonnestein',
#        'Zoutkeetsgracht', 'Zuiderzeeweg', 'Wibautstraat',
#        'Bos en Lommerweg', 'Bovenkruier', 'Brink', 'Dijkmanshuizenstraat',
#        'Ecuplein', 'Egidiusstraat', 'Elandsgracht', 'Europaplein',
#        'Florijn', 'Fred. Hendrikplants.', 'Frederiksplein', 'Gaasperplas',
#        'Dijkgraafplein', 'Gein', 'Grootzeil', 'Haarlemmermeerstraat',
#        'Haarlemmerplein', 'Heemstedestraat', 'Henk Sneevlietweg',
#        'Hoekenes', 'Hogeweg', 'Holendrechtplein', 'Hoofddorpplein',
#        'Gerrit v.d. Veenstraat', 'Diemerparklaan', 'Derkinderenstraat',
#        'Dennenrode', 'Brinkstraat', 'Buiten Brouwersstraat',
#        'Buiten Oranjestraat', 'Bullewijk', 'Burg. Fockstraat',
#        'Burg. R?ellstraat', 'Burg. Rendorpstraat', 'Burg. v. Leeuwenlaan',
#        'Burg.de Vlugtlaan', 'C. van Eesterenlaan', 'Ceintuurbaan',
#        'Centraal Station', 'Corn. Schuytstraat', 'Cornelis Troostplein',
#        'Dam', 'Dapperstraat', 'De Boelelaan/VU', 'De Pijp',
#        'De Sav. Lohmanstraat', 'De Wittenkade', 'Delflandlaan',
#        'Soembawastraat', 'Solebaystraat', 'Spaarndammerstraat',
#        'Spaklerweg', 'J. Drijverweg', 'De Rijpstraat', 'Hageland',
#        'Dr. H. Colijnstraat', 'G. v.Ledenberchstraat',
#        "Haarl'meerstation", 'Onderuit', 'Vijzelgracht', 'V.d. Hoopstraat',
#        'VU medisch centrum', 'Valeriusplein', 'Van Baerlestraat',
#        'Van Beuningenplein', 'Van Boshuizenstraat', 'Van Hallstraat',
#        'Van L.Stirumstraat', 'Van Woustraat', 'Uilenstede',
#        'Van der Madeweg', 'Vennepluimstraat', 'Venserpolder',
#        'Victorieplein', 'Veelaan', 'Tulastraat', 'Tjalkstraat',
#        'Spiegelgracht', 'Spinnerij', 'Sportlaan', 'Spui',
#        'Stadhouderskade', 'Statenjachtstraat', 'Station Bijlmer ArenA',
#        'Station Diemen-Zuid', 'Station Duivendrecht', 'Troelstralaan',
#        'Station Ganzenhoef', 'Station Lelylaan', 'Station Noord',
#        'Station RAI', 'Station Sloterdijk', 'Station Zuid',
#        'Steigereiland', 'Strandvliet', 'Surinameplein', 'Ten Katestraat',
#        'Station Holendrecht', 'Azartplein', 'Beukenplein', 'Bloemgracht',
#        'Burg. Eliasstraat', 'Amstelveen Centrum', 'Verrijn Stuartweg',
#        'Atat?rk', 'Barkpad', 'Wervershoofstraat', 'Majanggracht', 'Marne',
#        'Masthof', 'Karel Doormanstraat', 'Jan Evertsenstraat', 'Meent',
#        'Oostzanerdijk', 'Pinksterbloemstraat', 'Pr. Irenestraat',
#        'R.J.H. Fortuynplein', 'Meteorensingel', 'Middenweg', 'Mosplein',
#        'Nageljongenstraat', 'Nw.Willemsstraat', 'Petmolen', 'Purmerplein',
#        'Purmerweg', 'Minervaplein', 'Sierplein', 'Stadionweg',
#        'Standerdmolen', 'De Clercqstraat', 'Diemen (Sniep)', 'Flevopark',
#        'Gelderlandplein Oost', 'Bob Haarmslaan', 'Corantijnstraat',
#        'Gondel', 'Kastelenstraat', 'Hilversumstraat', 'Houtmankade',
#        'Markthallen', 'Beukenhorst', 'Contactweg', 'Vredenhof',
#        'Geerdinkhof', 'Koornhorst', 'Rode Kruisstraat', 'Tussendek',
#        'Sloterpark', 'Anderlechtlaan', 'Knooppunt Schiphol Nrd',
#        'De Egmondenstraat', 'Cateringweg', 'Nassauplein', 'Kattenburg',
#        'Oostelijke Handelskade', 'P.Oosterhuisstraat', 'Maanstraat',
#        'Valentijnkade', 'Tosaristraat', 'Zaaiersweg', 'Dostojevskisingel',
#        'Radioweg', 'Schiphol Verkeerstoren', 'Pieter Calandlaan',
#        'Erasmusgracht', 'Camperstraat', 'Kometensingel',
#        'Beethovenstraat', 'Buikslotermeerplein', 'Annie Romeinplein',
#        'Parnassusweg', 'Oosterlengte', 'Lumierestraat', 'Louweshoek',
#        'Stammerkamp', 'Tussen Meer', 'Tureluurweg', 'Slijperweg',
#        'Science Park Aqua', 'Science Park Aer', 'BovenIJ ziekenhuis',
#        'Bullepad', 'Burg. Bickerstraat', 'Cornelis Lelylaan',
#        'Bijlmerplein', 'Bornhout', 'Hogeschool InHolland', 'Hogevecht',
#        'Hoofdweg', 'Havikslaan', 'Echtenstein', 'Diemerknoop',
#        'Dolingadreef', 'Fizeaustraat', 'Haparandaweg', 'Gooioord',
#        'Geer Ban', 'Martin L.Kinglaan', 'Nieuw Herlaer',
#        'Linnaeusparkweg', 'Nieuwe Purmerweg', 'James Wattstraat',
#        'Jarmuiden', 'Kikkenstein', 'IJsbaanpad', 'Scheldeplein',
#        'Station Diemen', 'Van Heenvlietlaan', 'Aalsmeerplein',
#        'Anth. Moddermanstraat', 'Apollolaan', 'Vinkenbrug',
#        'Waddenwegviaduct', 'Distelweg', 'Casparuslaan',
#        'Robert Fruinlaan', 'Station Diemen Zuid', 'Pomonastraat',
#        'Winkelcentrum', 'Naritaweg', 'KNSM-laan', 'Krugerplein',
#        'Pres. Kennedylaan', 'Station Gein', 'Zeilstraat', 'Borneolaan',
#        'Willinklaan', 'Station Weesp', 'Station Science Park',
#        'Buiksloterwegveer', 'Zeezigt', 'Klipperweg', 'Ilperveldstraat',
#        'Saaftingestraat', 'Waddenweg', 'Geldershoofd',
#        'Peter Martensstraat', 'Scherpenzeelstraat', 'Amerbos', 'Staghof',
#        'Merelstraat', 'Reimerswaalstraat', 'Dintelstraat',
#        'Nachtwachtlaan', 'Brusselsingel', 'Archimedesweg', 'Grubbehoeve',
#        'Foppingadreef', 'Lorentzlaan', 'Tarwekamp',
#        'Jan van Zutphenplantsoen', 'Valkenweg', 'Buytenweg',
#        'Plataanstraat', 'Levantplein', 'Grasweg', 'Huigenbos',
#        'Industrieweg', 'Zuidermolenweg', 'Spaarndammerdijk', 'Kelbergen',
#        'Seineweg', 'Justus Lipsiusstraat', 'Jan Schaeferbrug',
#        'Johan v.Hasseltweg', 'De Boelelaan', 'Confuciusplein',
#        '[[ Onbekend ]]', 'Plesostraat', 'Leerdamhof', 'Fluitschipstraat',
#        'Bakkerswaal', 'Maasdrielhof', 'Osdorper Ban', 'Geinbrug',
#        'Diemen Noord', 'Spelderholt', 'Boven Rijkersloot',
#        'Maxwellstraat', 'Veenendaalplein', 'Station Reigersbos',
#        'Emmastraat', 'Herman Bonpad', 'Biesbosch', 'Floraweg',
#        'Naaldwijkstraat', 'Leusdenhof', 'Nw. Willemsstraat', 'Amstelpark',
#        'Hagedoornplein', 'Schoonhovendreef', 'Abberdaan', 'Antwerpenbaan',
#        'C. Mac Gillavrylaan', 'J. Cabeliaustraat', 'J.H.Leopoldhof',
#        'Oude Waelweg', 'Science Park', 'Liergouw', 'W. Gertenbachstraat',
#        'Schaarsbergenstraat', 'Westmallepad', 'Het Breed',
#        'Meidoornplein', 'Dalsteindreef', 'Pekelharingstraat',
#        'Westpoortweg', 'Staverdenplein', 'Zekeringstraat',
#        'Woudrichemstraat', 'V. M. Broeckmanstraat', 'V. Houten Ind.park',
#        'Maassluisstraat', 'Nelson Mandelapark', 'Ruimzicht',
#        'Th. Weeversweg', 'Pleimuiden', 'Skyport', 'Klaprozenweg',
#        'Aletta Jacobslaan', 'Jan Rebelstraat', 'Cura?aostraat',
#        'Ferd. Bolstraat', 'Wamelstraat', 'Hornhaven', 'Appelweg',
#        'Ottho Heldringstraat', 'Hemsterhuisstraat', 'Nieuwe Hemweg',
#        'Koos Vorrinkweg', 'Van Houtenlaan', 'Diemen Sniep',
#        'G.J. Scheurleerweg', 'C.K. Eloutstraat', 'Ananasplein',
#        'Bolstoen', 'Meernhof', 'Ruysdaelkade', 'Griendstraat',
#        'Burg. van Damstraat', 'Piet Heinkade', 'Herwijk', 'Oderweg',
#        "A'veen Busstation", 'P. Hendrikkade (uitstaphalte)',
#        'Kruidenommegang', 'Hakfort', 'Spreeuwenpark', 'Europaboulevard',
#        'Stationsweg', 'Banne Buikslootlaan', 'Groenhof', 'Praam',
#        'Logger', 'Middenhoven / Brink', 'Zagerij', 'Ziekenhuis', 'Seine',
#        'De Eindhoeve', 'Langerhuize', 'Dynamostraat', 'Hogewerf',
#        'Rhenenhof', 'Stadstuinen', 'L. Bouwmeesterstraat',
#        'Boven IJ Ziekenhuis', 'Jan de Louterpad', 'Oude Haagseweg',
#        'Plesmanlaan', 'Botterweg', 'Ouddiemerlaan', 'Maaseikpad',
#        'Schepenweg', 'Provincialeweg', 'Haardstee', 'Weteringcircuit',
#        'Plantage Parklaan', 'Busstat. Elandsgracht', 'Roetersstraat',
#        'Pr. Beatrixlaan', 'Berkenplein', 'Prins Bernhardlaan', 'Sky Port',
#        'W. v.Weldammelaan', 'Gaasp', 'Diemerbrug', 'Kattenburgerplein',
#        'Wittenburgergracht', 'Oostenburgergracht', 'Het Funen',
#        'Druivenstraat', 'Nolensstraat', 'Drentepark',
#        'P.A. v. Heyningestraat', 'Haarlemmermeerstation', 'La Meye',
#        'Metaalbewerkerweg', 'Koekoekslaan', 'Joan Muyskenweg',
#        'Westerdoksdijk', 'Droogbak', 'Molenaarsweg', 'Hamerstraat',
#        'Jan van Galenstraat', 'Station Spaklerweg', 'Bundlaan',
#        'IJ tunnel', 'Kastrupstraat', 'Amstelveen Stadshart',
#        'Allenstraat', 'Van Nijenrodeweg', 'Archangelkade',
#        'Utrechtsestraat', 'Talbotstraat', 'Bouvigne', 'Notweg',
#        'Eerste Marnixdwarsstraat', 'Stenendokweg', 'Scharenburg',
#        'Centrum Nieuw Sloten', 'Osdorpplein West', 'Osdorpplein Oost',
#        'Ookmeerweg', 'Belgi?plein', 'Osdorpplein Noord',
#        'C.v. Eesterenlaan', 'Volkstuin', 'Laarderhoogtweg',
#        'Paleisstraat', 'Paasheuvelweg', 'Concertgebouw',
#        'C. de Bourbonstraat', 'Van Hilligaertstraat',
#        'Prins Bernhardplein', 'Maltaweg', 'Durbanweg', 'Sicili?weg'],
#       dtype=object)

# %%
gvb_nieuwmarkt_checkin = gvb_checkin_hourly[gvb_checkin_hourly.HalteNaam == 'Nieuwmarkt']
gvb_dam_checkin = gvb_checkin_hourly[gvb_checkin_hourly.HalteNaam == 'Dam']

# %%
gvb_nieuwmarkt_checkout = gvb_checkout_hourly[gvb_checkout_hourly.HalteNaam == 'Nieuwmarkt']
gvb_dam_checkout = gvb_checkout_hourly[gvb_checkout_hourly.HalteNaam == 'Dam']

# %%
gvb_nieuwmarkt_checkin.dtypes
# Out:
# HalteNaam       object
# AantalReizen     int64
# datetime        object
# hour             int64
# week             int64
# month            int64
# year             int64
# weekday          int64
# dtype: object

# %%
# df.rename(columns={"A": "a", "B": "c"})

gvb_nieuwmarkt_checkin_copy = gvb_nieuwmarkt_checkin.copy()
gvb_nieuwmarkt_checkin_copy.rename(columns={'HalteNaam':'stop_name','AantalReizen':'count','datetime':'date'}, inplace=True)
gvb_nieuwmarkt_checkin_copy.drop(['week','month','year','weekday'], axis=1, inplace=True)
gvb_nieuwmarkt_checkin_copy.head()

gvb_nieuwmarkt_checkin_copy['datetime'] = gvb_nieuwmarkt_checkin_copy.date + " " + gvb_nieuwmarkt_checkin_copy.hour.astype(str) + ":00:00"
gvb_nieuwmarkt_checkin_copy.head()

# df['end_time'] = pd.to_datetime(df['end_time'], format=format_string)
gvb_nieuwmarkt_checkin_copy.datetime = pd.to_datetime(gvb_nieuwmarkt_checkin_copy.datetime)
# Out:
#       stop_name  count        date  hour
# 0    Nieuwmarkt     20  2019-01-01     0
# 78   Nieuwmarkt    409  2019-01-01    17
# 245  Nieuwmarkt    533  2019-01-01    18
# 572  Nieuwmarkt    296  2019-01-01    15
# 620  Nieuwmarkt    370  2019-01-01    16

# %%
gvb_nieuwmarkt_checkin_copy.dtypes
# Out:
# stop_name    object
# count         int64
# date         object
# hour          int64
# datetime     object
# dtype: object

# %%
def preprocessing(df):
    df.rename(columns={'HalteNaam':'stop_name','AantalReizen':'count','datetime':'date'}, inplace=True)
    df.drop(['week','month','year','weekday'], axis=1, inplace=True)
    df.sort_values(by=['date','hour'], inplace=True)
    df['datetime'] = df.date + " " + df.hour.astype(str) + ":00:00"
    df.datetime = pd.to_datetime(df.datetime)
    df = df[df.date >= "2020-09-01"]
    return df

# %%
gvb_nieuwmarkt_checkin = preprocessing(gvb_nieuwmarkt_checkin)
gvb_nieuwmarkt_checkout = preprocessing(gvb_nieuwmarkt_checkout)
gvb_dam_checkin = preprocessing(gvb_dam_checkin)
gvb_dam_checkout = preprocessing(gvb_dam_checkout)

# %%
gvb_nieuwmarkt_checkin.head()
# Out:
#           stop_name  count        date  hour            datetime
# 2305877  Nieuwmarkt     58  2020-09-01     0 2020-09-01 00:00:00
# 2305959  Nieuwmarkt     22  2020-09-01     6 2020-09-01 06:00:00
# 2305813  Nieuwmarkt     65  2020-09-01     7 2020-09-01 07:00:00
# 2305996  Nieuwmarkt    102  2020-09-01     8 2020-09-01 08:00:00
# 2305273  Nieuwmarkt     61  2020-09-01     9 2020-09-01 09:00:00

# %%
gvb_nieuwmarkt = pd.merge(gvb_nieuwmarkt_checkin, gvb_nieuwmarkt_checkout, on=['stop_name','date','hour','datetime'], how='outer')
gvb_nieuwmarkt.rename(columns={'count_x':'checkin', 'count_y':'checkout'}, inplace=True)
gvb_nieuwmarkt.sort_values(by=['date','hour'], inplace=True)
gvb_nieuwmarkt = gvb_nieuwmarkt[['stop_name', 'date', 'hour', 'datetime', 'checkin', 'checkout']]

# %%
gvb_nieuwmarkt.head()
# Out:
#     stop_name        date  hour            datetime  checkin  checkout
# 0  Nieuwmarkt  2020-09-01     0 2020-09-01 00:00:00     58.0      17.0
# 1  Nieuwmarkt  2020-09-01     6 2020-09-01 06:00:00     22.0      36.0
# 2  Nieuwmarkt  2020-09-01     7 2020-09-01 07:00:00     65.0      70.0
# 3  Nieuwmarkt  2020-09-01     8 2020-09-01 08:00:00    102.0     135.0
# 4  Nieuwmarkt  2020-09-01     9 2020-09-01 09:00:00     61.0     168.0

# %%
gvb_dam = pd.merge(gvb_dam_checkin, gvb_dam_checkout, on=['stop_name','date','hour','datetime'], how='outer')
gvb_dam.rename(columns={'count_x':'checkin', 'count_y':'checkout'}, inplace=True)
gvb_dam.sort_values(by=['date','hour'], inplace=True)
gvb_dam = gvb_dam[['stop_name', 'date', 'hour', 'datetime', 'checkin', 'checkout']]

# %%
gvb_dam.head()
# Out:
#      stop_name        date  hour            datetime  checkin  checkout
# 0          Dam  2020-09-01     0 2020-09-01 00:00:00     48.0       NaN
# 1          Dam  2020-09-01     1 2020-09-01 01:00:00     12.0       NaN
# 2          Dam  2020-09-01     2 2020-09-01 02:00:00     23.0       NaN
# 7039       Dam  2020-09-01     6 2020-09-01 06:00:00      NaN      32.0
# 7040       Dam  2020-09-01     7 2020-09-01 07:00:00      NaN      61.0

# %%
gvb_dam.to_csv("../data/gvb/gvb_dam.csv")

# %%
gvb_nieuwmarkt.to_csv("../data/gvb/gvb_nieuwmarkt.csv")

# %% [markdown]
# ## COVID stringency

# %%
covid = pd.read_csv("../data/netherlands-covid-stringency-index.csv", usecols=['Day', 'stringency_index'])
covid.head()
# Out:
#           Day  stringency_index
# 0  2020-01-21               0.0
# 1  2020-01-22               0.0
# 2  2020-01-23               0.0
# 3  2020-01-24               0.0
# 4  2020-01-25               0.0

# %%
covid = covid[covid.Day >= '2020-01-09']

# %%
covid.tail()
# Out:
#             Day  stringency_index
# 706  2021-12-27             63.89
# 707  2021-12-28             63.89
# 708  2021-12-29             63.89
# 709  2021-12-30             63.89
# 710  2021-12-31             63.89
